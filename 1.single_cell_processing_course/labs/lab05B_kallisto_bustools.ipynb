# %% [markdown]
# # Lab 5B: Quantification with kallisto | bustools (kb-python)
#
# ## Objectives
# - Understand pseudo-alignment and the BUS format
# - Run (or dry-run) kb-python for 10x data
# - Compare outputs to Cell Ranger
#
# ## Outputs
# - `results/lab05B_kb_notes.md`
# - key metrics copied into `results/processing_log.md`
#
# ---
#
# If you do not have kb-python installed, complete the **output anatomy + comparison** sections.

# %% [markdown]
# ## Terminal commands (template)
#
# ```bash
# # Install kb-python
# pip install kb-python
#
# # Prepare reference (one-time)
# # kb ref -i index.idx -g t2g.txt -f1 cdna.fa -f2 intron.fa genome.fa genes.gtf
#
# # Count (10x v3 example)
# kb count \
#   --workflow standard \
#   -i /absolute/path/to/index.idx \
#   -g /absolute/path/to/t2g.txt \
#   -x 10xv3 \
#   -o results/kb_pbmc_1k \
#   /absolute/path/to/R1.fastq.gz /absolute/path/to/R2.fastq.gz
#
# # Key outputs usually include:
# # - results/kb_pbmc_1k/counts_unfiltered/ or matrix outputs
# # - logs/ with run info
# ```
#
# ### Comparison checklist (kb vs Cell Ranger)
# - estimated cell count
# - genes per cell / UMIs per cell
# - run time + memory
# - notes on reference differences
